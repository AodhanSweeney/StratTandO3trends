# %%
import numpy as np
import pandas as pd
import xarray as xr
import xesmf as xe
import glob
import matplotlib.pyplot as plt
from scipy import stats
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.patches as patches
import pingouin as pg
from scipy import signal

colors = np.array([(22,98,248), (48,141,250), (71,172,251), (100,201,252), (129,222,253),(162,240,254), (215,249,253), (255,255,255),
                   (255,255,255), (255,249,217), (247,236,155), (254,221,128), (254,202,100), (255,173,71), (252,142,42), (255,101,15)])/255
custom_cmap = LinearSegmentedColormap.from_list('cmap', colors)

def trend_finder(temperature_anomalies_ts):
    """
    This function takes in a temperature timeseries and fits a linear trend to the data.
    temperature_anomalies_ts: the input is typically a zonal mean (i.e., heightxlatitude)
    timeseries which has already had the climatology removed and goes from 2002 to 2023.
    """

    map_of_trends = []
    for height_index in range(np.shape(temperature_anomalies_ts)[1]):
        trends_by_lat = []
        for lat_index in range(np.shape(temperature_anomalies_ts)[2]):
            temp_ts = temperature_anomalies_ts[:,height_index, lat_index]
            time = np.arange(2002, 2023, 1/12)/10
        
            try:
                #find trends and errors
                trend = stats.linregress(time, temp_ts)
                temp_trend = trend[0]
                temp_linear_trend = trend[1] + temp_trend*time
                errors = temp_ts - temp_linear_trend
                time_errors = time - np.nanmean(time)
                
                # find degrees of freedom with autocorrelation
                N = len(temp_ts)
                r1_autocorrelation = stats.pearsonr(temp_ts[1:], temp_ts[:-1])[0]
                N_star = N*((1-r1_autocorrelation)/
                            (1+r1_autocorrelation))
        
                # find squared error in x and y
                sum_squared_error_res = np.sum(np.square(errors))
                var_errors = (1/N_star)*sum_squared_error_res
                time_squared_error = np.sum(np.square(time_errors))
                simga_slope_squared = var_errors/time_squared_error
                sa = np.sqrt(simga_slope_squared)
                t_stat_calculated = temp_trend/sa

                # get critical t value
                tcrit = stats.t.ppf(1-0.025, N_star)

                # test for significance
                if np.abs(t_stat_calculated) > tcrit:
                    significance = 1
                else:
                    significance = 0
                
            except:
                temp_trend = np.nan
                significance = 0
            trends_by_lat.append([temp_trend, significance])
            
        map_of_trends.append(trends_by_lat)
    return(np.array(map_of_trends))

def detrender(time, ts):
    slope = stats.linregress(time, ts)[0]
    intercept = stats.linregress(time, ts)[1]
    recreation = intercept + slope*time
    ts_detrended = ts - recreation
    return(ts_detrended)

def QBO_ENSO_remover(ts, qbo1_ts, qbo2_ts, enso_ts):
    # detrend data
    time = np.arange(2002, 2023, 1/12)/10
    
    # create data frame for MLR
    predictors_and_target = [qbo1_ts, qbo2_ts, enso_ts, ts]
    df = pd.DataFrame(np.transpose(predictors_and_target), columns=['qbo1', 'qbo2', 'enso', 'temp'])

    # Predictors are time, qbo, and enso, Target is temp anomaly timeseries
    Preds = df[['qbo1', 'qbo2', 'enso']]
    Target = df['temp']
    
    # fit the multiple linear regression
    lm = pg.linear_regression(Preds, Target, add_intercept=True)
        
    # get coefficients of regression
    intercept = lm.coef[0]
    qbo1 = lm.coef[1]
    qbo2 = lm.coef[2]
    enso = lm.coef[3]

    # recreation with QBO and ENSO
    recreation = intercept + qbo1_ts*qbo1 + qbo2_ts*qbo2 + enso_ts*enso

    # find residual after removing the enso+qbo variability
    residual = ts - recreation
    
    return(residual)

# %%
new_pressure_levels = [1., 1.21152771, 1.46779931, 1.77827942,
                            2.15443468,    2.61015725,    3.1622777 ,    3.83118677,
                            4.64158869,    5.62341309,    6.81292057,    8.25404167,
                            10.        ,   12.11527634,   14.67799282,   17.78279495,
                            21.54434776,   26.10157204,   31.62277603,   38.31186676,
                            46.41588974,   56.23413086,   68.1292038 ,   82.54042053,
                            100.        ,  121.15276337,  146.77992249,  177.82794189,
                            215.44346619,  261.01571655,  300.        ,  316.22775269,
                            350.        ,  400.        ,  450.        ,  500.        ,
                            550.        ,  600.        ,  650.        ,  700.        ,
                            750.        ,  775.        ,  800.        ,  825.        ,
                            850.        ,  875.        ,  900.        ,  925.        ,
                            950.        ,  975.        , 1000.        ]

# %%
root_directory = '/home/disk/bdc2/aodhan/Zambri2020/O3*1995*'
O3_files = np.sort(glob.glob(root_directory))
T_root_directory = '/home/disk/bdc2/aodhan/Zambri2020/T*1995*'
U_root_directory = '/home/disk/bdc2/aodhan/Zambri2020/U*1995*'
T_files = np.sort(glob.glob(T_root_directory))
U_files = np.sort(glob.glob(U_root_directory))

# load T data
t_all_ens = []
u_all_ens = []
o3_all_ens = []
for file_idx, t_file in enumerate(T_files):
    xarray = xr.open_dataset(t_file).sel(time=slice('2002-01-01', '2022-12-31'))
    xarray_u = xr.open_dataset(U_files[file_idx]).sel(time=slice('2002-01-01', '2022-12-31'))
    xarray_o3 = xr.open_dataset(O3_files[file_idx]).sel(time=slice('2002-01-01', '2022-12-31'))
    
    # convert to pressure levels
    P0 = xarray.P0  # Reference pressure in Pa
    pressure = xarray['hyam'] * P0 + xarray['hybm'] * xarray['PS']
    standard_levels = xr.DataArray(new_pressure_levels, dims="level", name="pressure")
    
    # temp
    xarray = xarray.assign_coords(pressure=pressure)
    xarray = xarray.interp(lev=standard_levels)  # convert hPa to Pa
    
    # zonal wind
    xarray_u = xarray_u.assign_coords(pressure=pressure)
    xarray_u = xarray_u.interp(lev=standard_levels)
    
    # o3
    xarray_o3 = xarray_o3.assign_coords(pressure=pressure)
    xarray_o3 = xarray_o3.interp(lev=standard_levels)
    
    # define latitudes and levels
    lev = xarray.lev.values
    lats = xarray.lat.values
    
    # remove T climatologies
    t_data = xarray.T.values
    temp_cal = np.reshape(t_data, (21,12, len(lev), len(lats)))
    temp_seasonality = np.nanmean(temp_cal, axis=0)
    temp_anoms = temp_cal - temp_seasonality
    temp_anoms_ts = np.reshape(temp_anoms, (21*12, len(lev), len(lats)))
        
    # remove U climatologies
    u_data = xarray_u.U.values
    u_cal = np.reshape(u_data, (21,12, len(lev), len(lats)))
    u_seasonality = np.nanmean(u_cal, axis=0)
    u_anoms = u_cal - u_seasonality
    u_anoms_ts = np.reshape(u_anoms, (21*12, len(lev), len(lats)))
    
    # remove o3 climatologies
    o3_data_ppmv = xarray_o3.O3.values*1e6
    #o3_density_scaled =27.3*np.multiply(o3_data_ppmv, np.array(new_pressure_levels)[np.newaxis,:,np.newaxis])
    #o3_density = np.divide(o3_density_scaled, t_data)
    o3_cal = np.reshape(o3_data_ppmv, (21,12, len(lev), len(lats)))
    o3_seasonality = np.nanmean(o3_cal, axis=0)
    o3_anoms = o3_cal - o3_seasonality
    o3_anoms = np.divide(o3_anoms, o3_seasonality)*100
    o3_anoms_ts = np.reshape(o3_anoms, (21*12, len(lev), len(lats)))
    
    # create xarrays from data
    time = pd.date_range(start="2002-01-01", end="2022-12-01", freq='MS')
    t_anoms = xr.DataArray(temp_anoms_ts, coords={"time": time, "lev": lev, "lat": lats}, dims=["time", "lev", "lat"])
    u_anoms = xr.DataArray(u_anoms_ts, coords={"time": time, "lev": lev, "lat": lats}, dims=["time", "lev", "lat"])
    o3_anoms = xr.DataArray(o3_anoms_ts, coords={"time": time, "lev": lev, "lat": lats}, dims=["time", "lev", "lat"])
    
    # append data
    t_all_ens.append(t_anoms)
    u_all_ens.append(u_anoms)
    o3_all_ens.append(o3_anoms)

# get concatenated ensemble members
ens_t = xr.concat(t_all_ens, dim='ens_num')
ens_u = xr.concat(u_all_ens, dim='ens_num')
ens_o3 = xr.concat(o3_all_ens, dim='ens_num')

# get ensemble means
ens_t_mean = ens_t.mean(dim='ens_num')
ens_u_mean = ens_u.mean(dim='ens_num')
ens_o3_mean = ens_o3.mean(dim='ens_num')


# remove the interannual variability from each ensemble member and find trends
trends_all = []
o3_anoms_all = []
for ens_idx in range(10):
    # find ensemble member
    t_ens_data = ens_t.isel(ens_num=ens_idx)
    u_ens_data = ens_u.isel(ens_num=ens_idx)
    o3_ens_data = ens_o3.isel(ens_num=ens_idx)
    
    # remove ensemble mean from each ensemble memeber
    t_ens_data_mr = t_ens_data - ens_t_mean
    
    # get the internal variability
    Teq = t_ens_data_mr.sel(lat=slice(-15,15)).mean(dim='lat').values
    T500_anoms_ts = Teq[:,35]
    
    # get zonal wind at 30 hPa
    u30 = ens_u_mean.sel(lat=slice(-5,5)).mean(dim='lat').values
    u30_anoms_ts = u30[:,18]

    # get zonal wind at 10 hPa
    u10 = ens_u_mean.sel(lat=slice(-5,5)).mean(dim='lat').values
    u10_anoms_ts = u10[:,12]

    # remove the QBO and ENSO
    o3_anoms_data = []
    for lev_index in range(0, len(lev)):
        levs_line = []
        for lat_index in range(0, len(lats)):
            try:
                new_anom_ts = QBO_ENSO_remover(o3_ens_data.values[:,lev_index,lat_index], u10_anoms_ts, u30_anoms_ts, T500_anoms_ts)
            except:
                new_anom_ts = o3_ens_data.values[:,lev_index,lat_index]
            levs_line.append(new_anom_ts)
        o3_anoms_data.append(levs_line)
    o3_anoms_data = np.swapaxes(o3_anoms_data, 0,2)
    o3_anoms_data = np.swapaxes(o3_anoms_data, 1,2)
    
    o3_anoms_ts = o3_anoms_data
    trend_map = trend_finder(o3_anoms_ts)
    trends_all.append(trend_map)
    o3_anoms_all.append(o3_anoms_ts)


trends_all = np.array(trends_all)[:,:,:,0]
signs = np.sign(trends_all)
positive_counts = np.sum(signs > 0, axis=0)
negative_counts = np.sum(signs < 0, axis=0)
mask = (positive_counts >= 9) | (negative_counts >= 9)
significance = mask.astype(int)
ens_mean_anom = np.nanmean(o3_anoms_all, axis=0)
mean_trend = trend_finder(ens_mean_anom)
# Out:
# /home/disk/p/aodhan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:41: RuntimeWarning: Mean of empty slice
# /home/disk/p/aodhan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:48: RuntimeWarning: Mean of empty slice
# /home/disk/p/aodhan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:57: RuntimeWarning: Mean of empty slice
# /home/disk/p/aodhan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:130: RuntimeWarning: invalid value encountered in greater
# /home/disk/p/aodhan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:131: RuntimeWarning: invalid value encountered in less
# /home/disk/p/aodhan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:134: RuntimeWarning: Mean of empty slice

# %%
AWLS_trend = mean_trend[22:25,30:42,0]
print(len(lev), lev[22:25])
print(len(lats), lats[30:42])
print(np.shape(AWLS_trend))
lat_weights = np.cos(np.deg2rad(lats[30:42]))
AWLS_trend = np.multiply(AWLS_trend, lat_weights[np.newaxis, :])
AWLS_trend = np.reshape(AWLS_trend, (len(AWLS_trend)*12))
AWLS_trend = np.nansum(AWLS_trend)/(np.sum(lat_weights)*3)
print(AWLS_trend)
# Out:
# 51 [ 68.1292038   82.54042053 100.        ]
# 96 [-33.15789474 -31.26315789 -29.36842105 -27.47368421 -25.57894737
#  -23.68421053 -21.78947368 -19.89473684 -18.         -16.10526316
#  -14.21052632 -12.31578947]
# (3, 12)
# 1.6425351224312674

# %%
lrz = np.load('/home/disk/p/aodhan/cf_physical_parameters_correlations/tempmaps/lrz_maps_zm_annual_mean.npy')
def alt2pres(altitude):
    H = 7
    press = 1000*np.exp(-1*(altitude/H))
    return press
lrp = alt2pres(lrz)
levels = np.arange(-0.55,0.551,.1)*10

fig, axs = plt.subplots(1,1, figsize=(6,4))

titles = ['Member 1', 'Member 2', 'Member 3', 'Member 4', 'Mean']

for i in range(0, len([axs])):
    axs.contour(lats, lev, mean_trend[:,:,0], levels=levels,colors='black', extend='both', linewidths=0.5, linestyles=np.where(levels >= 0, "-", "-"))
    im = axs.contourf(lats, lev, mean_trend[:,:,0], levels=levels,cmap=custom_cmap, extend='both')
    axs.plot(np.linspace(-90,90,36), lrp, color='black')
    axs.set_yscale('log')
    axs.invert_yaxis()
    axs.set_xlim(-82,82)
    axs.set_ylim(300,10)
    axs.grid(alpha=0.5)
    cbar = plt.colorbar(im)
    plt.contourf(lats, lev, mean_trend[:,:,1], levels=[-1, 0, 1], colors='none', hatches=[None,'.'])
    #rect = patches.Rectangle((-33.75, 80.), 15, 20, linewidth=2, edgecolor='red', facecolor='none')
    #plt.gca().add_patch(rect)
    
cbar.set_ticks(np.array([-0.45,-0.25, -0.05, 0.05, 0.25,0.45])*10)
x_vals = [-75, -50, -25, 0, 25, 50, 75]
plt.xticks(x_vals)
plt.tick_params(axis='both', which='major', labelsize=13)
#plt.savefig('/home/disk/p/aodhan/GNSSTrends/figures/WACCMOzoneEnsMean.png', dpi=300)

# %%
fig, axs = plt.subplots(2,5, figsize=(24,8))
axes = axs.ravel()

for i in range(0, len(axes)):
    ax = axes[i]
    ax.contour(lats, lev, trends_all[i,:,:], levels=levels,colors='black', extend='both', linewidths=0.5, linestyles=np.where(levels >= 0, "-", "-"))
    im = ax.contourf(lats, lev, trends_all[i,:,:], levels=levels,cmap=custom_cmap, extend='both')
    #ax.contourf(lats, lev, trends_all[i,:,:,1], levels=[-1, 0, 1], colors='none', hatches=[None,'.'])
    ax.plot(np.linspace(-90,90,36), lrp, color='black')
    ax.set_yscale('log')
    ax.invert_yaxis()
    ax.set_xlim(-80,80)
    ax.set_ylim(300,10)
    ax.grid(alpha=0.5)
    #plt.colorbar(im)
    #plt.contourf(lats, lev, trends_all[i,:,:,1], levels=[-1, 0, 1], colors='none', hatches=[None,'.'])
    #rect = patches.Rectangle((-33.75, 80.), 15, 20, linewidth=2, edgecolor='red', facecolor='none')
    #plt.gca().add_patch(rect)

# %%
ens_mean_anom = np.nanmean(o3_anoms_all, axis=0)
# Out:
# /home/disk/p/aodhan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: Mean of empty slice
#   """Entry point for launching an IPython kernel.

# %%
def seasonal_trend_finder(time_non_nans, temp_non_nans):
    # find residual timeseries
    trend = stats.linregress(time_non_nans, temp_non_nans)
    temp_trend = trend[0]
    temp_linear_trend = trend[1] + temp_trend*time_non_nans
    errors = temp_non_nans - temp_linear_trend
    time_errors = time_non_nans - np.nanmean(time_non_nans)


    # find degrees of freedom with autocorrelation
    N = len(temp_non_nans)
    r1_autocorrelation = stats.pearsonr(temp_non_nans[1:], temp_non_nans[:-1])[0]
    N_star = N*((1-r1_autocorrelation)/
                (1+r1_autocorrelation))

    # find squared error in x and y
    sum_squared_error_res = np.sum(np.square(errors))
    var_errors = (1/N_star)*sum_squared_error_res
    time_squared_error = np.sum(np.square(time_errors))
    simga_slope_squared = var_errors/time_squared_error
    sa = np.sqrt(simga_slope_squared)
    t_stat_calculated = temp_trend/sa

    # get critical t value
    tcrit = stats.t.ppf(1-0.025, N_star)
    if np.abs(t_stat_calculated) > tcrit:
        significance = 1
    else:
        significance = 0
    return([temp_trend, significance])

def MLR_map_season(temperature_anomalies_ts, s1, s2, s3):
    resid_map = []
    map_mlr = []
    for height_index in range(np.shape(temperature_anomalies_ts)[1]):
        mlr_by_lat = []
        for lat_index in range(np.shape(temperature_anomalies_ts)[2]):
            temp_ts = temperature_anomalies_ts[:,height_index, lat_index]
            time = np.arange(2002, 2023, 1/12)/10

            time_cal = np.reshape(time, (21,12))
            temp_cal = np.reshape(temp_ts, (21,12))

            time = np.transpose([time_cal[:,s1], time_cal[:,s2], time_cal[:,s3]]).ravel()
            temp_ts = np.transpose([temp_cal[:,s1], temp_cal[:,s2], temp_cal[:,s3]]).ravel()
            

            # find non nan values
            temp_non_nans = temp_ts[~np.isnan(temp_ts)]
            time_non_nans = time[~np.isnan(temp_ts)]

            try:
                raw_trend_sig = seasonal_trend_finder(time_non_nans, temp_non_nans)                
                mlr_by_lat.append(raw_trend_sig)
            except:
                nan_trend_sig = [np.NaN, np.NaN]
                mlr_by_lat.append(nan_trend_sig)
        map_mlr.append(mlr_by_lat)
    return(np.array(map_mlr))


DJF  = MLR_map_season(ens_mean_anom, 0,1,11)
MAM  = MLR_map_season(ens_mean_anom, 2,3,4)
JJA  = MLR_map_season(ens_mean_anom, 5,6,7)
SON  = MLR_map_season(ens_mean_anom, 8,9,10)
seasons = [DJF, MAM, JJA, SON]

# %%
levels = np.arange(-0.55,0.551,.1)*20
fig, axs = plt.subplots(1,4, figsize=(20,5))
axes = axs.ravel()
for x in range(len(seasons)):
    axes[x].contour(lats, lev, seasons[x][:,:,0], levels=levels,colors='black', extend='both', linewidths=0.5, linestyles=np.where(levels >= 0, "-", "-"))
    axes[x].contourf(lats, lev,  seasons[x][:,:,0], levels=levels,cmap=custom_cmap, extend='both')
    axes[x].contourf(lats, lev, seasons[x][:,:,1], levels=[-1, 0, 1], colors='none', hatches=[None,'.'])
    axs[x].set_yscale('log')
    axs[x].invert_yaxis()
    axs[x].plot(np.linspace(-90,90,36), lrp, color='black')    
    axes[x].set_ylim(300,10)
    axes[x].set_xlim(-80,80)
    axes[x].grid(alpha=0.5)
    axes[x].tick_params(axis='both', which='major', labelsize=20)
    
#plt.savefig('/home/disk/p/aodhan/GNSSTrends/figures/WACCMOzoneEnsMeanSeasonal.png', dpi=300)
# Out:
# /home/disk/p/aodhan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: No contour levels were found within the data range.
#   """

# %% [markdown]
# # get monthly variation

# %%
def MLR_map_month(temperature_anomalies_ts, s1):
    resid_map = []
    map_mlr = []
    for height_index in range(np.shape(temperature_anomalies_ts)[1]):
        mlr_by_lat = []
        for lat_index in range(np.shape(temperature_anomalies_ts)[2]):
            temp_ts = temperature_anomalies_ts[:,height_index, lat_index]
            time = np.arange(2002, 2023, 1/12)/10

            time_cal = np.reshape(time, (21,12))
            temp_cal = np.reshape(temp_ts, (21,12))

            time = np.transpose([time_cal[:,s1]]).ravel()
            temp_ts = np.transpose([temp_cal[:,s1]]).ravel()
            

            # find non nan values
            temp_non_nans = temp_ts[~np.isnan(temp_ts)]
            time_non_nans = time[~np.isnan(temp_ts)]

            try:
                raw_trend_sig = seasonal_trend_finder(time_non_nans, temp_non_nans)                
                mlr_by_lat.append(raw_trend_sig)
            except:
                nan_trend_sig = [np.NaN, np.NaN]
                mlr_by_lat.append(nan_trend_sig)
        map_mlr.append(mlr_by_lat)
    return(np.array(map_mlr))

jan  = MLR_map_month(ens_mean_anom, 0)
feb  = MLR_map_month(ens_mean_anom, 1)
mar  = MLR_map_month(ens_mean_anom, 2)
apr  = MLR_map_month(ens_mean_anom, 3)
may  = MLR_map_month(ens_mean_anom, 4)
jun  = MLR_map_month(ens_mean_anom, 5)
jul  = MLR_map_month(ens_mean_anom, 6)
aug  = MLR_map_month(ens_mean_anom, 7)
sep  = MLR_map_month(ens_mean_anom, 8)
occ  = MLR_map_month(ens_mean_anom, 9)
nov  = MLR_map_month(ens_mean_anom, 10)
dec  = MLR_map_month(ens_mean_anom, 11)

# %%
months1 = [jan, feb, mar, apr, may, jun]
months2 = [jul, aug, sep, occ, nov, dec]

levels = np.arange(-0.55,0.551,.1)*2
fig, axs = plt.subplots(1,6, figsize=(28,5))
axes = axs.ravel()
for x in range(len(months1)):
    axes[x].contour(lats, lev, months2[x][:,:,0], levels=levels,colors='black', extend='both', linewidths=0.5, linestyles=np.where(levels >= 0, "-", "-"))
    axes[x].contourf(lats, lev,  months2[x][:,:,0], levels=levels,cmap=custom_cmap, extend='both')
    axes[x].contourf(lats, lev, months2[x][:,:,1], levels=[-1, 0, 1], colors='none', hatches=[None,'.'])
    axs[x].set_yscale('log')
    axs[x].invert_yaxis()
    axs[x].plot(np.linspace(-90,90,36), lrp, color='black')    
    axes[x].set_ylim(300,10)
    axes[x].set_xlim(-80,80)
    axes[x].grid(alpha=0.5)
    axes[x].tick_params(axis='both', which='major', labelsize=20)

# %%
print(np.shape(mean_trend))
# Out:
# (66, 96)

# %%
import numpy as np
from scipy.interpolate import interp1d 
from scipy.interpolate import RectBivariateSpline

# Original grid dimensions
new_pressure_levels = [1., 1.21152771, 1.46779931, 1.77827942,
                            2.15443468,    2.61015725,    3.1622777 ,    3.83118677,
                            4.64158869,    5.62341309,    6.81292057,    8.25404167,
                            10.        ,   12.11527634,   14.67799282,   17.78279495,
                            21.54434776,   26.10157204,   31.62277603,   38.31186676,
                            46.41588974,   56.23413086,   68.1292038 ,   82.54042053,
                            100.        ,  121.15276337,  146.77992249,  177.82794189,
                            215.44346619,  261.01571655,  300.        ,  316.22775269,
                            350.        ,  400.        ,  450.        ,  500.        ,
                            550.        ,  600.        ,  650.        ,  700.        ,
                            750.        ,  775.        ,  800.        ,  825.        ,
                            850.        ,  875.        ,  900.        ,  925.        ,
                            950.        ,  975.        , 1000.        ]
new_latitudes = [-86.25, -78.75, -71.25, -63.75, -56.25, -48.75, -41.25, -33.75, 
                      -26.25, -18.75, -11.25,  -3.75,   3.75,  11.25,  18.75,  26.25, 
                      33.75,  41.25,  48.75,  56.25,  63.75,  71.25,  78.75,  86.25]

# New grid dimensions
original_pressure_levels = lev
original_latitudes = lats

# Sample data (replace this with your actual data)
data = mean_trend[:,:,0]

# Create the interpolation function
interpolator = interp1d(original_latitudes, data, axis=-1)

# Interpolate the data to the new grid
new_data = interpolator(new_latitudes)

print(new_data.shape)
# Out:
# (51, 24)

# %%
np.save('/home/disk/p/aodhan/GNSSTrends/TrendAnalysis/Zambri2020/ozone_trends_WACCM4_regridded', new_data)

# %%
print(np.shape(new_data))
# Out:
# (51, 24)

# %%
plt.contourf(new_data)
